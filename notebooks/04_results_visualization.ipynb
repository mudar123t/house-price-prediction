# %%
import sys, os
sys.path.append(os.path.abspath('..'))
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Model comparison across pipeline stages

# %%
from src.visualization import plot_model_comparison
plot_model_comparison(stage="test_set_final")

# %% [markdown]
# ## Feature importance

# %%
from src.visualization import plot_feature_importance
plot_feature_importance()

# %% [markdown]
# ## Actual vs Predicted (test set)

# %%
from src.visualization import plot_actual_vs_predicted
plot_actual_vs_predicted()

# %% [markdown]
# ## Residual analysis

# %%
from src.visualization import plot_residuals
plot_residuals()
